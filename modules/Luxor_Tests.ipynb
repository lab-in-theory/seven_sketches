# %%
using Luxor, Colors

Drawing(1200, 1400)

origin()
cols = diverging_palette(60, 120, 20) # hue 60 to hue 120
background(cols[1])
setopacity(0.7)
setline(2)

setcolor(cols[rand(2:20)])
p1 = Point(-500, -450)
p2 = Point(-100, -450)

circle(p1, 50, :fill)
circle(p2, 50, :fill)

setcolor(cols[rand(2:20)])
setfont("Sans Serif", 40)
t1 = Point(p1[1]-13, p1[2]+17)
t2 = Point(p2[1]-13, p2[2]+17)
settext("1", t1)
settext("2", t2)

setcolor(cols[rand(2:20)])
a_start = Point(p1[1]+50, -450)
a_end   = Point(p2[1]-50, -450)
arrow(a_start, a_end,
    linewidth = 3.0,
    arrowheadlength = 20,
    arrowheadangle = pi/8)

finish()
preview()

# %%
push!(LOAD_PATH, "/Users/erin/Documents/julia-workspace/modules")
using Operators

f(x) = 2*x
X = [1,2,3,]


X ↦ f
